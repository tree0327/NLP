# %% [markdown]
# # 📊 2. 빈도 기반 벡터화: 단어 개수 세기 (BoW & TF-IDF)
#
# 가장 쉽고 직관적인 방법이야. **"많이 나온 단어가 중요하겠지?"** 라는 단순한 생각에서 출발해!
#
# ## 1. Bag of Words (BoW): "장바구니" 🧺
#
# *   **개념**: 문법, 순서 다 무시하고 그냥 **장바구니(Bag)**에 단어를 다 때려 넣고 몇 개인지 세는 거야.
# *   **비유**: "이 문장에는 '사과'가 2개, '바나나'가 1개 들어있네!"
# *   **단점**: '나', '는', '이' 같은 쓸모없는 단어도 많이 나오면 중요하다고 착각해.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

sentences = [
    'I love my dog.',
    'I love my cat.',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

# 1. BoW 만드는 기계 (CountVectorizer) 가져오기
vectorizer = CountVectorizer()

# 2. 문장 학습 및 변환 (단어장 만들고 + 개수 세기)
features = vectorizer.fit_transform(sentences)

# 3. 결과 확인 (단어 이름들)
vocab = vectorizer.get_feature_names_out()
print("단어장 목록:", vocab)

# 4. 표(DataFrame)로 예쁘게 보기
bow_df = pd.DataFrame(features.toarray(), columns=vocab)
bow_df
# Out:
# 단어장 목록: ['amazing' 'cat' 'do' 'dog' 'is' 'love' 'my' 'think' 'you']
#    amazing  cat  do  dog  is  love  my  think  you
# 0        0    0   0    1   0     1   1      0    0
# 1        0    1   0    0   0     1   1      0    0
# 2        0    0   0    1   0     1   1      0    1
# 3        1    0   1    1   1     0   1      1    1

# %% [markdown]
# ---

# %% [markdown]
# ## 2. TF-IDF: "진짜 주인공 찾기" ✨
#
# 단순히 개수만 세니까('love', 'my') 같은 흔한 단어가 1등을 해버리지?
# 그래서 **"흔한 단어는 점수를 깎고, 희귀한 단어에 가산점을 주자!"** 라는 아이디어가 나왔어.
#
# ### 공식 (핵심만!)
# $$ \text{TF-IDF} = TF \times IDF $$
#
# 1.  **TF (Term Frequency)**: 여기서 몇 번 나왔니? (많을수록 점수 UP ⬆️)
# 2.  **IDF (Inverse Document Frequency)**: 다른 문서에서도 흔하니? (흔할수록 점수 DOWN ⬇️)
#
# > **결과**: "여기서만 많이 나온 단어"(예: `Genome`, `Nuclear`)가 높은 점수를 받게 돼!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 1. TF-IDF 기계 가져오기
tfidf_vectorizer = TfidfVectorizer()

# 2. 변환
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)

# 3. 표로 보기
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vocab)
tfidf_df.round(2)  # 소수점 2자리까지만
# Out:
#    amazing   cat    do   dog    is  love    my  think   you
# 0     0.00  0.00  0.00  0.61  0.00  0.61  0.50   0.00  0.00
# 1     0.00  0.77  0.00  0.00  0.00  0.49  0.40   0.00  0.00
# 2     0.00  0.00  0.00  0.49  0.00  0.49  0.40   0.00  0.60
# 3     0.43  0.00  0.43  0.28  0.43  0.00  0.23   0.43  0.34

# %% [markdown]
# ### 💡 결과 분석
# - 아까 **BoW**에서는 `love`나 `dog`가 숫자가 컸지?
# - **TF-IDF** 표를 보면, `amazing`이나 `think` 같은 단어가 점수가 꽤 높아진 걸 볼 수 있어.
# - 왜? `love`는 개나 소나 다 쓰니까 가치가 떨어지고, **`amazing`은 4번 문장에만 등장한 희귀한 단어**라 가치가 높은 거야!

# %% [markdown]
# ## 🎓 마무리 퀴즈
#
# **Q. 'a', 'the' 같은 관사는 모든 문서에 아주 많이 등장합니다. TF-IDF에서 이 단어들의 점수는?**
# 1. 아주 높다 (개수가 많으니까)
# 2. 아주 낮다 (IDF 페널티 때문에)
#
# <details>
# <summary>정답 확인</summary>
#
# **2번** (이게 TF-IDF를 쓰는 이유야! 흔한 녀석 점수 깎기!)
#
# </details>
